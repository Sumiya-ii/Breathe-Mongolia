# %% [markdown]
# # Air Quality Data Analysis - Mongolian National Broadcaster(MNB)
# ## Sumiya Ganbaatar
# ### Data Source: https://aqicn.org/city/ulaanbaatar/mnb/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import calplot

# %%
# Loading the dataset
mnb = pd.read_csv("/Users/bayarmaaorsoo/Desktop/Breathe Mongolia/Data Analysis/Ulaanbaatar Data Analysis/Data CSV/m.n.b.,-ulaanbaatar-air-quality.csv")

# %%
mnb.head()
# Out:
#        date  pm25  pm10  o3  no2  so2  co
# 0  2022/2/2   253
# 1  2022/1/4   246    76   7    3   76
# 2  2022/1/5   231    76   8    3   81
# 3  2022/1/6   232    85   7    3   88
# 4  2022/1/7   260    85   7    3   86

# %% [markdown]
# In this dataset, there is no raw data and every pollutants' data recorded in daily average AQI.

# %% [markdown]
# ## Data Transformation

# %%
#Doing some data cleaning for other data sets

#Converting data type of date (object to datetime)
mnb['date'] = pd.to_datetime(mnb['date'])

#MNB
mnb.columns = mnb.columns.str.replace(' ','')
mnb = mnb.sort_values(by = 'date', ascending = False)
cols_to_convert_mnb = mnb.columns.drop('date')
mnb[cols_to_convert_mnb] = mnb[cols_to_convert_mnb].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ## Data Visualizations
#
# ### MNB - PM2.5 (Line plot & Scatter plot)

# %%
# MNB PM2.5

# Main line plot
plt.figure(figsize=(25,10))
sns.lineplot(x = 'date', y = 'pm25', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM2.5 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 420, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=57, color='deepskyblue', linestyle='dotted', linewidth = 4)
#plt.text(pd.Timestamp('2022-01-15'), 62, "WHO PM2.5 standard", horizontalalignment='left', fontsize=22, color='deepskyblue')

#plt.axhline(y=137, color='r', linestyle='dotted', linewidth = 4)
#plt.text(pd.Timestamp('2022-01-15'), 142, "Mongolian National PM2.5 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 14)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
plt.axhspan(150, 200, facecolor='red', alpha=0.4)
plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("PM2.5 AQI", fontsize = 15)
plt.title("PM2.5 AQI - Mongolian National Broadcaster", fontsize = 22)

# Yearly change

plt.text(pd.Timestamp('2015-04-30'), 370, "-12.7%", horizontalalignment='left', fontsize=22, color='red')
plt.text(pd.Timestamp('2016-04-1'), 400, "+20.9%", horizontalalignment='left', fontsize=22, color='green')
plt.text(pd.Timestamp('2017-05-10'), 400, "-20%", horizontalalignment='left', fontsize=22, color='red')
plt.text(pd.Timestamp('2018-04-30'), 370, "+4.4%", horizontalalignment='left', fontsize=22, color='green')
plt.text(pd.Timestamp('2019-05-20'), 330, "-16.8%", horizontalalignment='left', fontsize=22, color='red')
plt.text(pd.Timestamp('2020-04-30'), 300, "-3.3%", horizontalalignment='left', fontsize=22, color='red')
plt.text(pd.Timestamp('2021-05-10'), 280, "-4.8%", horizontalalignment='left', fontsize=22, color='red')
# Out:
# Text(2021-05-10 00:00:00, 280, '-4.8%')

# %%
# MNB PM2.5

# Main scatter plot
plt.figure(figsize=(25,10))
plt.scatter(x = 'date', y = 'pm25', data =mnb, color = 'black', linewidth = 0.1, alpha = 0.7)

# Some important date and PM2.5 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 420, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=57, color='deepskyblue', linestyle='dotted', linewidth = 4)
#plt.text(pd.Timestamp('2022-01-15'), 62, "WHO PM2.5 standard", horizontalalignment='left', fontsize=22, color='deepskyblue')

#plt.axhline(y=137, color='r', linestyle='dotted', linewidth = 4)
#plt.text(pd.Timestamp('2022-01-15'), 142, "Mongolian National PM2.5 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 14)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
plt.axhspan(150, 200, facecolor='red', alpha=0.4)
plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("PM2.5 AQI", fontsize = 15)
plt.title("PM2.5 AQI- Mongolian National Broadcaster", fontsize = 22)

# Yearly change

plt.text(pd.Timestamp('2015-04-30'), 370, "-12.7%", horizontalalignment='left', fontsize=22, color='red')
plt.text(pd.Timestamp('2016-04-1'), 400, "+20.9%", horizontalalignment='left', fontsize=22, color='green')
plt.text(pd.Timestamp('2017-05-10'), 400, "-20%", horizontalalignment='left', fontsize=22, color='red')
plt.text(pd.Timestamp('2018-04-30'), 370, "+4.4%", horizontalalignment='left', fontsize=22, color='green')
plt.text(pd.Timestamp('2019-05-20'), 330, "-16.8%", horizontalalignment='left', fontsize=22, color='red')
plt.text(pd.Timestamp('2020-04-30'), 300, "-3.3%", horizontalalignment='left', fontsize=22, color='red')
plt.text(pd.Timestamp('2021-05-10'), 280, "-4.8%", horizontalalignment='left', fontsize=22, color='red')
# Out:
# Text(2021-05-10 00:00:00, 280, '-4.8%')

# %% [markdown]
# ### MNB - PM10 - (Line plot & Scatter plot)

# %%
#MNB PM10

# Main line plot
plt.figure(figsize=(25,10))
sns.lineplot(x = 'date', y = 'pm10', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 420, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
plt.axhspan(150, 200, facecolor='red', alpha=0.4)
plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("PM10 AQI", fontsize = 15)
plt.title("PM10 AQI- Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'PM10 AQI- Mongolian National Broadcaster')

# %%
#MNB PM10

# Main scatter plot
plt.figure(figsize=(25,10))
sns.scatterplot(x = 'date', y = 'pm10', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 420, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
plt.axhspan(150, 200, facecolor='red', alpha=0.4)
plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("PM10 AQI", fontsize = 15)
plt.title("PM10 AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'PM10 AQI - Mongolian National Broadcaster')

# %% [markdown]
# ### MNB - NO2 - (Line plot & Scatter plot)

# %%
#MNB NO2

# Main line plot
plt.figure(figsize=(25,10))
sns.lineplot(x = 'date', y = 'no2', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 40, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
#plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
#plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
#plt.axhspan(150, 200, facecolor='red', alpha=0.4)
#plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
#plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("NO2 AQI", fontsize = 15)
plt.title("NO2 AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'NO2 AQI - Mongolian National Broadcaster')

# %%
#MNB NO2

# Main scatter plot
plt.figure(figsize=(25,10))
sns.scatterplot(x = 'date', y = 'no2', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 40, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
#plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
#plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
#plt.axhspan(150, 200, facecolor='red', alpha=0.4)
#plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
#plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("NO2 AQI", fontsize = 15)
plt.title("NO2 AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'NO2 AQI - Mongolian National Broadcaster')

# %% [markdown]
# ### MNB - SO2 (Line plot & Scatter plot)

# %%
#MNB SO2

# Main line plot
plt.figure(figsize=(25,10))
sns.lineplot(x = 'date', y = 'so2', data =mnb, color = 'black', linewidth = 0.7)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 40, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
#plt.axhspan(150, 200, facecolor='red', alpha=0.4)
#plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
#plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("SO2 AQI", fontsize = 15)
plt.title("SO2 AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'SO2 AQI - Mongolian National Broadcaster')

# %%
#MNB SO2

# Main scatter plot
plt.figure(figsize=(25,10))
sns.scatterplot(x = 'date', y = 'so2', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 40, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
#plt.axhspan(150, 200, facecolor='red', alpha=0.4)
#plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
#plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("SO2 AQI", fontsize = 15)
plt.title("SO2 AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'SO2 AQI - Mongolian National Broadcaster')

# %% [markdown]
# ### MNB - CO (Line plot & Scatter plot)

# %%
#MNB CO

# Main scatter plot
plt.figure(figsize=(25,10))
sns.lineplot(x = 'date', y = 'co', data =mnb, color = 'black', linewidth = 1)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 40, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
#plt.axhspan(150, 200, facecolor='red', alpha=0.4)
#plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
#plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("CO AQI", fontsize = 15)
plt.title("CO AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'CO AQI - Mongolian National Broadcaster')

# %%
#MNB CO

# Main scatter plot
plt.figure(figsize=(25,10))
sns.scatterplot(x = 'date', y = 'co', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 40, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
#plt.axhspan(150, 200, facecolor='red', alpha=0.4)
#plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
#plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("CO AQI", fontsize = 15)
plt.title("CO AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'SO2 AQI - Mongolian National Broadcaster')

# %% [markdown]
# ### MNB - O3 - (Line plot & Scatter plot)

# %%
#MNB O3

# Main line plot
plt.figure(figsize=(25,10))
sns.lineplot(x = 'date', y = 'o3', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 200, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category
plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
plt.axhspan(150, 200, facecolor='red', alpha=0.4)
#plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
#plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("O3 AQI", fontsize = 15)
plt.title("O3 AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'O3 AQI - Mongolian National Broadcaster')

# %% [markdown]
# ### MNB - 03 - Scatter plot

# %%
#MNB O3

# Main scatter plot
plt.figure(figsize=(25,10))
sns.scatterplot(x = 'date', y = 'o3', data =mnb, color = 'black', linewidth = 0.5)

# Some important date and PM10 values
plt.axvline(pd.Timestamp('2019-05-15'), linewidth = 2, color = 'b')
plt.text(pd.Timestamp('2019-05-25'), 200, "Ban of raw coal", horizontalalignment='left', fontsize=22, color='b')

#plt.axhline(y=45, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 55, "WHO PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#plt.axhline(y=100, color='r', linestyle='-', linewidth = 2)
#plt.text(pd.Timestamp('2022-01-15'), 110, "National PM10 standard", horizontalalignment='left', fontsize=22, color='red')

#Legends
legend_elements = [Patch(facecolor='darkred', label='Hazardous', alpha = 0.5),
                  Patch(facecolor='purple', label='Very unhealthy', alpha = 0.5),
                  Patch(facecolor='red', label='Unhealthy', alpha = 0.5),
                  Patch(facecolor='orange', label='Unhealthy for sensitive people', alpha = 0.5),
                  Patch(facecolor='yellow', label='Moderate', alpha = 0.5),
                  Patch(facecolor='green', label='Good', alpha = 0.5)]

plt.legend(handles=legend_elements, loc='upper right', fontsize = 16)

#AQI category

plt.axhspan(0, 50, facecolor='green', alpha=0.4)
plt.axhspan(50, 100, facecolor='yellow', alpha=0.4)
plt.axhspan(100, 150, facecolor='orange', alpha=0.4)
plt.axhspan(150, 200, facecolor='red', alpha=0.4)
#plt.axhspan(200, 300, facecolor='purple', alpha=0.4)
#plt.axhspan(300, 500, facecolor='darkred', alpha=0.4)

#Label

plt.xlabel("Date", fontsize = 15)
plt.ylabel("O3 AQI", fontsize = 15)
plt.title("O3 AQI - Mongolian National Broadcaster", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'O3 AQI - Mongolian National Broadcaster')

# %% [markdown]
# ## Stacked bar chart - PM2.5

# %%
# Creating a new dataset for stacked bar chart
mnb1 = mnb
mnb1['year'] = mnb['date'].dt.year
mnb1['month'] = mnb['date'].dt.month
mnb1 = mnb1.bfill()

# %%
column_names = ["2015", "2016", "2017", "2018", "2019", "2020", "2021"]

stack_bar_data = pd.DataFrame(columns = column_names)

# Percentage of 'Hazardous' days by years

for i in [2015, 2016, 2017, 2018, 2019, 2020, 2021]:
    stack_bar_data = stack_bar_data.append({str(i): (len(mnb1[(mnb1['year'] == i) &(mnb1['pm25'] > 300)])) /
                           (len(mnb1[mnb1['year'] == i]))}, ignore_index = True)

stack_bar_data = stack_bar_data.bfill().ffill()
stack_bar_data = stack_bar_data.drop_duplicates(keep='first')

# Percentage of 'Very Unhealthy' days by years

for i in [2015, 2016, 2017, 2018, 2019, 2020, 2021]:
    stack_bar_data = stack_bar_data.append({str(i): (len(mnb1[(mnb1['year'] == i) &
                                                              (mnb1['pm25'] <= 300) &
                                                              (mnb1['pm25'] > 200)])) /
                                            (len(mnb1[mnb1['year'] == i]))}, ignore_index = True)

stack_bar_data = stack_bar_data.bfill().ffill()
stack_bar_data = stack_bar_data.drop_duplicates(keep='first')

# Percentage of 'Unhealthy' days by years

for i in [2015, 2016, 2017, 2018, 2019, 2020, 2021]:
    stack_bar_data = stack_bar_data.append({str(i): (len(mnb1[(mnb1['year'] == i) &
                                                              (mnb1['pm25'] <= 200) &
                                                              (mnb1['pm25'] > 150)])) /
                                            (len(mnb1[mnb1['year'] == i]))}, ignore_index = True)

stack_bar_data = stack_bar_data.bfill().ffill()
stack_bar_data = stack_bar_data.drop_duplicates(keep='first')

# Percentage of 'Unhealthy for sensitive peaople' days by years

for i in [2015, 2016, 2017, 2018, 2019, 2020, 2021]:
    stack_bar_data = stack_bar_data.append({str(i): (len(mnb1[(mnb1['year'] == i) &
                                                              (mnb1['pm25'] <= 150) &
                                                              (mnb1['pm25'] > 100)])) /
                                            (len(mnb1[mnb1['year'] == i]))}, ignore_index = True)

stack_bar_data = stack_bar_data.bfill().ffill()
stack_bar_data = stack_bar_data.drop_duplicates(keep='first')

# Percentage of 'Moderate' days by years

for i in [2015, 2016, 2017, 2018, 2019, 2020, 2021]:
    stack_bar_data = stack_bar_data.append({str(i): (len(mnb1[(mnb1['year'] == i) &
                                                              (mnb1['pm25'] <= 100) &
                                                              (mnb1['pm25'] > 50)])) /
                                            (len(mnb1[mnb1['year'] == i]))}, ignore_index = True)

stack_bar_data = stack_bar_data.bfill().ffill()
stack_bar_data = stack_bar_data.drop_duplicates(keep='first')


# Percentage of 'Good' days by years

for i in [2015, 2016, 2017, 2018, 2019, 2020, 2021]:
    stack_bar_data = stack_bar_data.append({str(i): (len(mnb1[(mnb1['year'] == i) &
                                                              (mnb1['pm25'] <= 50) &
                                                              (mnb1['pm25'] >= 0)])) /
                                            (len(mnb1[mnb1['year'] == i]))}, ignore_index = True)

stack_bar_data = stack_bar_data.bfill().ffill()
stack_bar_data = stack_bar_data.drop_duplicates(keep='first')

# %%
# Changing row names
stack_bar_data = stack_bar_data.set_axis(['Hazardous', 'Very Unhealthy', 'Unhealthy', 
             'Unhealthy for sensitive people', 'Moderate', 'Good'], axis=0)

# Transposing the dataset
stack_bar_data = stack_bar_data.T

# %%
stack_bar_data
# Out:
#       Hazardous  Very Unhealthy  Unhealthy  Unhealthy for sensitive people  \
# 2015   0.113260        0.190608   0.143646                        0.171271
# 2016   0.117318        0.153631   0.139665                        0.189944
# 2017   0.115942        0.156522   0.159420                        0.185507
# 2018   0.074586        0.160221   0.102210                        0.174033
# 2019   0.060976        0.198171   0.167683                        0.143293
# 2020   0.002770        0.149584   0.163435                        0.199446
# 2021   0.002825        0.135593   0.186441                        0.189266
#
#       Moderate      Good
# 2015  0.339779  0.041436
# 2016  0.349162  0.050279
# 2017  0.292754  0.089855
# 2018  0.375691  0.113260
# 2019  0.365854  0.064024
# 2020  0.254848  0.229917
# 2021  0.313559  0.172316

# %%
# Variables
labels = ['Hazardous', 'Very Unhealthy', 'Unhealthy', 'Unhealthy for sensitive people', 'Moderate', 'Good']
colors = ['darkred', 'purple', 'red', 'darkorange', 'yellow', 'green']
title = 'Percentage of Days by AQI Categories and Years\n'


def plot_stackedbar_p(df, labels, colors, title):
    fields = df.columns.tolist()
    
    # figure and axis
    fig, ax = plt.subplots(1, figsize=(20, 8))
# plot bars
    left = len(df) * [0]
    for idx, name in enumerate(fields):
        plt.barh(df.index, df[name], left = left, color=colors[idx])
        left = left + df[name]
# title and subtitle
    plt.title(title, loc='left', fontsize = 17)

# legend
    plt.legend(labels, bbox_to_anchor=([0.58, 1, 0, 0]), ncol=3, frameon=False)
# remove spines
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
# format x ticks
    xticks = np.arange(0,1.1,0.1)
    xlabels = ['{}%'.format(i) for i in np.arange(0,101,10)]
    plt.xticks(xticks, xlabels)
# adjust limits and draw grid lines
    plt.ylim(-0.5, ax.get_yticks()[-1] + 0.5)
    ax.xaxis.grid(color='gray', linestyle='dashed')
plt.show()
    
plot_stackedbar_p(stack_bar_data, labels, colors, title)

# %% [markdown]
# ## Calendar plot - MNB - PM2.5

# %%
import calplot
import numpy as np; np.random.seed(sum(map(ord, 'calplot')))
import pandas as pd

mnbcal = mnb.set_index('date')

# %%
calplot.calplot(mnbcal['pm25'], 
                cmap='afmhot_r', 
                suptitle = 'Daily Average PM2.5 AQI in MNB',
                textformat ='{:.0f}',
                textfiller = '-',
               figsize=(30, 30))
# Out:
# (<Figure size 2160x2160 with 10 Axes>,
#  array([<AxesSubplot:ylabel='2014'>, <AxesSubplot:ylabel='2015'>,
#         <AxesSubplot:ylabel='2016'>, <AxesSubplot:ylabel='2017'>,
#         <AxesSubplot:ylabel='2018'>, <AxesSubplot:ylabel='2019'>,
#         <AxesSubplot:ylabel='2020'>, <AxesSubplot:ylabel='2021'>,
#         <AxesSubplot:ylabel='2022'>], dtype=object))

# %% [markdown]
# ## Some calculations

# %%
mnb.groupby(mnb.date.dt.year).mean()
# Out:
#             pm25        pm10         o3        no2        so2         co
# date
# 2014  258.231884  266.289855        NaN  16.246377  23.462687  31.811594
# 2015  160.210084  135.694678  24.540000  16.705882  24.769231  17.815126
# 2016  154.095775  108.455056  32.587349  17.210674  27.365714  16.460674
# 2017  157.199413   99.726471  25.628159  17.524927  25.466049  19.450311
# 2018  136.824713   90.701149  20.571429  16.402235  30.274648  13.348837
# 2019  144.693252   63.064417        NaN   7.870307  14.202532        NaN
# 2020  131.526490   49.980198  10.426667   7.984985  32.375000        NaN
# 2021  118.280000   44.402857  23.290780   3.837121  25.757143        NaN
# 2022  215.952381   69.900000  10.000000   2.750000  72.550000        NaN

# %%
mnb.pm25.groupby(mnb.date.dt.year).mean()
# Out:
# date
# 2014    258.231884
# 2015    160.210084
# 2016    154.095775
# 2017    157.199413
# 2018    136.824713
# 2019    144.693252
# 2020    131.526490
# 2021    118.280000
# 2022    205.818182
# Name: pm25, dtype: float64

# %% [markdown]
#  ## Yearly changes
#
#  2014-2015 258.2 - 233.7  -9.5%
#
#  2015-2016 160.2 - 154 -3.8%
#
#  2016-2017 154 - 157.2 +2%
#
#  2017-2018 157.2 - 136.8 -13%
#
#  2018-2019 136.8 - 144.6 +5.7%
#
#  2019-2020 144.6 - 131.5 -9%
#
#  2020-2021 131.5 - 118.2 -10.1%
#
#  2021-2022 215.4 - 215.9

# %% [markdown]
# ### PM2.5 changes between winters
#
# ##### (ex: 2019 Winter = 2018/06/01 - 2019/06/01 )
#
# 2015 winter - 2016 winter (217.5 -182.4) -16.1%
#
# 2016 winter - 2017 winter (144 -169) +17.3%
#
# 2017 winter - 2018 winter (169 - 139.5) -17.4%
#
# 2018 winter - 2019 winter (139.5 -152.9) +9.6%
#
# 2019 winter - 2020 winter (152.9 - 124) -18.9%
#
# 2020 winter - 2021 winter (124 - 131.4) +5.9%
#
# 2021 winter - 2022 winter (160 - 152.2) -4.8%
#
# ##### (ex: 2019 Winter = 2018/09/01 - 2019/03/01 )
#
# 2015 winter - 2016 winter (271.6 - 237.1) -12.7%
#
# 2016 winter - 2017 winter (200 - 241.8 ) +20.9%
#
# 2017 winter - 2018 winter (241.8 - 193.4) -20%
#
# 2018 winter - 2019 winter (193.4 - 202) +4.4%
#
# 2019 winter - 2020 winter (202 - 168.1) -16.8%
#
# 2020 winter - 2021 winter (168.1 - 162.5) -3.3%
#
# 2021 winter - 2022 winter (160 - 152.3) -4.8%
